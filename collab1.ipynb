# %% [markdown]
# <a href="https://colab.research.google.com/github/Prdazk/BELAJAR-CSS-LENGKAP/blob/main/collab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#/content/sample_data/autumn-forest-passage-dirt-road-seasons-landscape-scenery-5k-6144x4101-5842.jpg

## baca gambar
import cv2
img = cv2.imread('/content/sample_data/autumn-forest-passage-dirt-road-seasons-landscape-scenery-5k-6144x4101-5842.jpg')


## tampilkan gambar
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %% [markdown]
# # New Section
